# %% [markdown]
# Declaramos las variables:

# %%
# variables.py
import numpy as np

# Barcos (nombre: eslora)
BARCOS = {
    "barco_1": 1,
    "barco_2": 1,
    "barco_3": 1,
    "barco_4": 1,
    "barco_5": 2,
    "barco_6": 2,
    "barco_7": 2,
    "barco_8": 3,
    "barco_9": 3,
    "barco_10": 4,
}
# Tableros
tablero = np.full((10,10), " ") 
tablero_limitado = np.full((10,10), " ")

# Jugadores
#jugador_A = 
#jugador_B = 

# Símbolos usados en el tablero
agua = " "
barco = "O"
tocado = "X"
fallo = "-"
